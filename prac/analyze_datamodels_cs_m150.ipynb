# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
import sys
sys.path.append('../')
from fast_l1.logger import Reader

# %%
r = Reader('/home/seiyunshin/datamodels-3/log_dir/reg_results/regularization_path/')

# %%
# Plot training and validation MSE
plt.plot(r.read_field(field_name='train_mse', index=1)[5:], label='Train Margin')
plt.plot(r.read_field(field_name='val_mse', index=1)[5:], label='Validation Margin')

# Add axis labels
plt.xlabel("Epochs")  # X-axis label
plt.ylabel("Margin")  # Y-axis label

# Add title (caption)
plt.title("Training vs Validation Margin over Epochs") 

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.plot(r.read_field(field_name='train_mse', index=1)[5:])
plt.show()

# %%
import numpy as np
print(np.where(~r.read_field(field_name='still_optimizing_outer', index=1))[0][0])
print(np.where(r.read_field(field_name='last_lambda', index=1)[10:])[0][0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 import numpy as np
# ----> 2 print(np.where(~r.read_field(field_name='still_optimizing_outer', index=1))[0][0])
#       3 print(np.where(r.read_field(field_name='last_lambda', index=1)[10:])[0][0])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
plt.plot(r.read_field(field_name='lambda', index=1)[5:], label='lambda')

# Add axis labels
plt.xlabel("Epochs")  # X-axis label
plt.ylabel("Lambda")  # Y-axis label

# Add title (caption)
plt.title("Regularization coefficient over Epochs") 

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
arr = r.read_field(field_name='train_mse', index=1)
print(len(arr))
# Out:
# 33
